# %% [markdown]
# # 문장 토큰 단위 분류 모델 학습 (with CRF Layer)
#
# > 작성자
# ```
# * 김성현 (bananaband657@gmail.com)
# 4기 멘토
# 이녕우 (leenw2@gmail.com)
# 박채훈 (qkrcogns2222@gmail.com)
# ```
# [CC BY-NC-ND](https://creativecommons.org/licenses/by-nc-nd/2.0/kr/)

# %% [markdown]
# ###**콘텐츠 라이선스**
#
# <font color='red'><b>**WARNING**</b></font> : **본 교육 콘텐츠의 지식재산권은 재단법인 네이버커넥트에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다.** 다만, 비영리적 교육 및 연구활동에 한정되어 사용할 수 있으나 재단의 허락을 받아야 합니다. 이를 위반하는 경우, 관련 법률에 따라 책임을 질 수 있습니다.

# %% [markdown]
# ###**실습 내용**
#
# 이번 실습에서는 [(7강-실습-1)에서 진행했던 BERT 기반의 문장 토큰 분류 모델 학습](https://colab.research.google.com/drive/1IAwgODugZ4Hc50Qb7xYVpxMHqGEd4ClH)을 CRF Layer가 추가된 모델로 학습해보려 합니다.
#
# *   [BERTForTokenClassification class](https://huggingface.co/docs/transformers/model_doc/bert#transformers.BertForTokenClassification)를 override하여 CRF layer를 추가합니다.
# *   CRF(Conditional Random Field)는 sequential labeling 을 위하여 potential functions 을 이용하는 softmax regression입니다 [[cite]](https://lovit.github.io/nlp/2018/09/13/crf_based_tagger/).
# *   CRF 모델은 Deep learning 계열 모델이 sequential labeling 에 이용되기 전에, 다른 많은 모델보다 좋은 성능을 보인다고 알려진 모델으로, 우리는 이 섹션에서 해당 모델을 구현하고, 이전 섹션에서 학습한 모델과 비교합니다.
#
#
# 앞의 코드는 (7강-실습-1)과 동일하며, **9. pytorch-crf 패키지 설치** 섹션부터 실습을 진행하시면 됩니다.
# 중간 중간에 있는 주석 부분을 채워서 제출해주세요!

# %% [markdown]
# ### 1. CPU 및 GPU 환경설정

# %%
import torch
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %% [markdown]
# ### 2. 데이터셋

# %%
# !git clone https://github.com/kmounlp/NER.git
# Out:
# fatal: destination path 'NER' already exists and is not an empty directory.

# %%
import os
import glob

# %%
file_list = []

# %%
for x in os.walk('/content/NER/'):
    for y in glob.glob(os.path.join(x[0], '*_NER.txt')):    # ner.*, *_NER.txt
        file_list.append(y)

# %%
file_list = sorted(file_list)

# %%
for file_path in file_list:
    print(file_path)
# Out:
# /content/NER/말뭉치 - 형태소_개체명/00002_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00003_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00004_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00005_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00006_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00007_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00008_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00009_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00010_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00011_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00012_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00013_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00014_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00015_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00016_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00017_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00018_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00019_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00020_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00021_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00022_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00023_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00024_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00025_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00026_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00027_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00028_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00029_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00030_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00031_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00032_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00033_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00034_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00035_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00036_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00037_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00038_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00039_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00040_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00041_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00042_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00043_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00044_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00045_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00046_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00047_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00048_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00049_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00050_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00051_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00052_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00053_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00054_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00055_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00056_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00057_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00058_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00059_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00060_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00061_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00062_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00063_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00064_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00065_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00066_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00067_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00068_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00069_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00070_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00071_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00072_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00073_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00074_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00075_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00076_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00077_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00078_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00079_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00080_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00081_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00082_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00083_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00084_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00085_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00086_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00087_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00088_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00089_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00090_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00091_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00092_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00093_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00094_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00095_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00096_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00097_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00098_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00099_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00100_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00101_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00102_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00103_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00104_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00105_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00106_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00107_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00108_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00109_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00110_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00111_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00112_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00113_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00114_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00115_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00116_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00117_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00119_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00120_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00121_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00122_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00123_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00124_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/00125_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/
NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32564_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32565_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32566_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32567_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32568_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32569_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32570_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32571_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32572_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32573_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32574_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32575_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32576_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32577_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32578_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32579_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32580_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32581_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32582_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32583_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32584_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32585_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32586_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32587_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32588_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32589_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32590_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32591_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32592_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32593_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32594_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32595_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32596_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32597_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32598_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32599_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32600_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32601_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32602_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32603_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32604_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32605_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32606_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32607_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32608_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32609_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32610_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32611_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32612_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32613_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32614_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32615_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32616_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32617_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32618_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32619_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32620_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32621_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32622_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32623_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32624_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32625_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32626_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32627_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32628_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32629_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32630_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32631_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32632_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32633_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32634_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32635_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32636_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32637_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32638_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32639_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32640_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32641_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32642_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32643_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32644_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32645_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32646_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32647_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32648_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32649_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32650_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32651_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32652_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32653_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32654_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32655_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32656_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32657_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32658_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32659_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32660_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32661_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32662_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32663_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32664_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32665_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32666_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32667_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32668_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32669_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32670_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32671_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32672_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32673_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32674_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32675_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32676_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32677_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32678_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32679_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32680_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32681_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32682_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32683_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32684_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32685_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32686_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32687_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32688_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32689_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32690_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32691_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32692_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32693_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32694_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32695_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32696_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32697_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32698_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32699_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32700_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32701_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32702_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32703_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32704_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32705_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32706_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32707_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32708_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32709_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32710_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32711_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32712_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32713_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32714_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32715_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32716_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32717_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32718_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32719_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32720_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32721_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32722_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32723_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32724_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32725_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32726_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32727_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32728_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32729_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32730_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32731_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32732_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32733_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32734_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32735_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32736_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32737_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32738_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32739_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32740_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32741_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32742_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32743_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32744_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32745_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32746_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32747_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32748_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32749_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32750_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32751_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32752_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32753_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32754_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32755_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32756_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32757_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32758_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32759_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32760_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32761_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32762_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32763_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32764_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32765_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32766_NER.txt
# /content/NER/말뭉치 - 형태소_개체명/32767_NER.txt

# %% [markdown]
# ### 3. 허깅페이스 트랜스포머 설치

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 27.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 63.0 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 64.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.9.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.1 transformers-4.23.1

# %% [markdown]
# ### 4. 데이터셋 샘플

# %%
from pathlib import Path

# %%
file_path = file_list[0]
file_path = Path(file_path)
raw_text = file_path.read_text().strip()

# %%
print(raw_text[0:1000])
# Out:
# ## 1
# ## 오에 겐자부로는 일본 현대문학의 초석을 놓은 것으로 평가받는 작가 나쓰메 소세키(1867~1916)의 대표작 ‘마음’에 담긴 군국주의적 요소, 야스쿠니 신사 참배 행위까지 소설의 삽화로 동원하며 일본 사회의 ‘비정상성’을 문제 삼는다.
# ## <오에 겐자부로:PER>는 <일본:LOC> 현대문학의 초석을 놓은 것으로 평가받는 작가 <나쓰메 소세키:PER>(<1867~1916:DUR>)의 대표작 ‘<마음:POH>’에 담긴 군국주의적 요소, <야스쿠니 신사:ORG> 참배 행위까지 소설의 삽화로 동원하며 <일본:ORG> 사회의 ‘비정상성’을 문제 삼는다.
# 오에	오에	NNG	B-PER
# _	_	_	I-PER
# 겐자부로	겐자부로	NNP	I-PER
# 는	는	JX	O
# _	_	_	O
# 일본	일본	NNP	B-LOC
# _	_	_	O
# 현대	현대	NNG	O
# 문학	문학	NNG	O
# 의	의	JKG	O
# _	_	_	O
# 초석	초석	NNG	O
# 을	을	JKO	O
# _	_	_	O
# 놓	놓	VV	O
# 은	은	ETM	O
# _	_	_	O
# 것	것	NNB	O
# 으로	으로	JKB	O
# _	_	_	O
# 평가	평가	NNG	O
# 받	받	VV	O
# 는	는	ETM	O
# _	_	_	O
# 작가	작가	NNG	O
# _	_	_	O
# 나쓰메	나쓰메	NNP	B-PER
# _	_	_	I-PER
# 소세키	소세키	NNP	I-PER
# (	(	SS	O
# 1867	1867	SN	B-DUR
# ~	~	SO	I-DUR
# 1916	1916	SN	I-DUR
# )	)	SS	O
# 의	의	JKG	O
# _	_	_	O
# 대표작	대표작	NNG	O
# _	_	_	O
# ‘	‘	SS	O
# 마음	마음	NNG	B-POH
# ’	’	SS	O
# 에	에	JKB	O
# _	_	_	O
# 담긴	담기+ㄴ	VV+ETM	O
# _	_	_	O
# 군국주의	군국주의	NNG	O
# 적	적	XSN	O
# _	_	_	O
# 요소	요소	NNG	O
# ,	,	SP	O
# _	_	_	O
# 야스쿠니	야스쿠니	NNP	B-ORG
# _	_	_	I-ORG
# 신사	신사	NNG	I-ORG
# _	_	_	O
# 참배	참배	NNG	O
# _	_	_	O
# 행위	행위	NNG	O
# 까지	까지	JX	O
# _	_	_	O
# 소설

# %% [markdown]
# ### 5. 데이터셋 전처리

# %%
import re

# %%
def read_file(file_list):
    token_docs = []
    tag_docs = []
    for file_path in file_list:
        # print("read file from ", file_path)
        file_path = Path(file_path)
        raw_text = file_path.read_text().strip()
        raw_docs = re.split(r'\n\t?\n', raw_text)
        for doc in raw_docs:
            tokens = []
            tags = []
            for line in doc.split('\n'):
                if line[0:1] == "$" or line[0:1] == ";" or line[0:2] == "##":
                    continue
                try:
                    token = line.split('\t')[0]
                    tag = line.split('\t')[3]   # 2: pos, 3: ner
                    for i, syllable in enumerate(token):    # 음절 단위로 잘라서
                        tokens.append(syllable)
                        modi_tag = tag
                        if i > 0:
                            if tag[0] == 'B':
                                modi_tag = 'I' + tag[1:]    # BIO tag를 부착할게요 :-)
                        tags.append(modi_tag)
                except:
                    print(line)
            token_docs.append(tokens)
            tag_docs.append(tags)

    return token_docs, tag_docs

# %%
texts, tags = read_file(file_list[:])

# %%
print(len(texts))
print(len(tags))
# Out:
# 19263
# 19263

# %%
print(texts[0], end='\n\n') # 음절 단위로 잘 잘렸네요!
print(tags[0])
# Out:
# ['오', '에', '_', '겐', '자', '부', '로', '는', '_', '일', '본', '_', '현', '대', '문', '학', '의', '_', '초', '석', '을', '_', '놓', '은', '_', '것', '으', '로', '_', '평', '가', '받', '는', '_', '작', '가', '_', '나', '쓰', '메', '_', '소', '세', '키', '(', '1', '8', '6', '7', '~', '1', '9', '1', '6', ')', '의', '_', '대', '표', '작', '_', '‘', '마', '음', '’', '에', '_', '담', '긴', '_', '군', '국', '주', '의', '적', '_', '요', '소', ',', '_', '야', '스', '쿠', '니', '_', '신', '사', '_', '참', '배', '_', '행', '위', '까', '지', '_', '소', '설', '의', '_', '삽', '화', '로', '_', '동', '원', '하', '며', '_', '일', '본', '_', '사', '회', '의', '_', '‘', '비', '정', '상', '성', '’', '을', '_', '문', '제', '_', '삼', '는', '다', '.']
#
# ['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'I-DUR', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-POH', 'I-POH', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
unique_tags = set(tag for doc in tags for tag in doc)
tag2id = {tag: id for id, tag in enumerate(unique_tags)}
id2tag = {id: tag for tag, id in tag2id.items()}

# %%
for i, tag in enumerate(unique_tags):
    print(tag)  # 학습을 위한 label list를 확인합니다.
# Out:
# I-PNT
# I-POH
# B-POH
# B-PER
# B-LOC
# B-ORG
# I-ORG
# I-TIM
# B-DUR
# B-DAT
# I-NOH
# I-DUR
# I-PER
# I-LOC
# I-DAT
# B-MNY
# B-NOH
# B-TIM
# O
# I-MNY
# B-PNT

# %% [markdown]
# ### 6. Train Test Split

# %%
from sklearn.model_selection import train_test_split
train_texts, test_texts, train_tags, test_tags = train_test_split(texts, tags, test_size=.2)

# %%
print('Train 문장 : {:>6,}' .format(len(train_texts)))
print('Train 태그 : {:>6,}' .format(len(train_tags)))
print('Test  문장 : {:>6,}' .format(len(test_texts)))
print('Test  태그 : {:>6,}' .format(len(test_tags)))
# Out:
# Train 문장 : 15,410
# Train 태그 : 15,410
# Test  문장 :  3,853
# Test  태그 :  3,853

# %% [markdown]
# ### 7. BERT 토크나이저

# %%
from transformers import AutoModel, AutoTokenizer, BertTokenizer
MODEL_NAME = "bert-base-multilingual-cased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.96M [00:00<?, ?B/s]

# %%
pad_token_id = tokenizer.pad_token_id # 0
cls_token_id = tokenizer.cls_token_id # 101
sep_token_id = tokenizer.sep_token_id # 102
pad_token_label_id = tag2id['O']    # tag2id['O']
cls_token_label_id = tag2id['O']
sep_token_label_id = tag2id['O']

# %%
def ner_tokenizer(sent, max_seq_length):    
    pre_syllable = "_"
    input_ids = [pad_token_id] * (max_seq_length - 1)
    attention_mask = [0] * (max_seq_length - 1)
    token_type_ids = [0] * max_seq_length
    sent = sent[:max_seq_length-2]

    for i, syllable in enumerate(sent):
        if syllable == '_':
            pre_syllable = syllable
        if pre_syllable != "_":
            syllable = '##' + syllable  # 중간 음절에는 모두 prefix를 붙입니다.
            # 이순신은 조선 -> [이, ##순, ##신, ##은, 조, ##선]
        pre_syllable = syllable

        input_ids[i] = (tokenizer.convert_tokens_to_ids(syllable))
        attention_mask[i] = 1
    
    input_ids = [cls_token_id] + input_ids
    input_ids[len(sent)+1] = sep_token_id
    attention_mask = [1] + attention_mask
    attention_mask[len(sent)+1] = 1
    return {"input_ids":input_ids,
            "attention_mask":attention_mask,
            "token_type_ids":token_type_ids}

# %%
print(ner_tokenizer(train_texts[0], 5))
# Out:
# {'input_ids': [101, 9331, 10459, 168, 102], 'attention_mask': [1, 1, 1, 1, 1], 'token_type_ids': [0, 0, 0, 0, 0]}

# %%
tokenized_train_sentences = []
tokenized_test_sentences = []
for text in train_texts:    # 전체 데이터를 tokenizing 합니다.
    tokenized_train_sentences.append(ner_tokenizer(text, 128))
for text in test_texts:
    tokenized_test_sentences.append(ner_tokenizer(text, 128))

# %%
def encode_tags(tags, max_seq_length):
    # label 역시 입력 token과 개수를 맞춰줍니다 :-)
    tags = tags[:max_seq_length-2]
    labels = [tag2id[tag] for tag in tags]
    labels = [tag2id['O']] + labels

    padding_length = max_seq_length - len(labels)
    labels = labels + ([pad_token_label_id] * padding_length)

    return labels

# %%
encode_tags(train_tags[0], 5)
# Out:
# [18, 18, 18, 18, 18]

# %%
train_labels = []
test_labels = []

for tag in train_tags:
    train_labels.append(encode_tags(tag, 128))

for tag in test_tags:
    test_labels.append(encode_tags(tag, 128))

# %%
len(train_labels), len(test_labels)
# Out:
# (15410, 3853)

# %% [markdown]
# ### 8. Token 데이터셋

# %%
import torch

class TokenDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val) for key, val in self.encodings[idx].items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = TokenDataset(tokenized_train_sentences, train_labels)
test_dataset = TokenDataset(tokenized_test_sentences, test_labels)

# %%
from transformers import BertForTokenClassification, Trainer, TrainingArguments
import sys
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=5,              # total number of training epochs
    per_device_train_batch_size=8,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    logging_dir='./logs',            # directory for storing logs
    logging_steps=100,
    learning_rate=3e-5,
    save_total_limit=5
)

# %% [markdown]
# ### 9. pytorch-crf 패키지 설치

# %%
# !pip install pytorch-crf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-crf
#   Downloading pytorch_crf-0.7.2-py3-none-any.whl (9.5 kB)
# Installing collected packages: pytorch-crf
# Successfully installed pytorch-crf-0.7.2

# %% [markdown]
# ### 10. BERTForTokenClassification class overriding 후 CRF Layer 추가

# %%
from transformers import BertPreTrainedModel, BertModel
from transformers.modeling_outputs import  TokenClassifierOutput
from torch import nn
from torch.nn import CrossEntropyLoss

from torchcrf import CRF

from typing import List, Optional, Tuple, Union

# %%
class BertCRFForTokenClassification(BertPreTrainedModel):

    _keys_to_ignore_on_load_unexpected = [r"pooler"]

    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels

        self.bert = BertModel(config, add_pooling_layer=False)
        classifier_dropout = (
            config.classifier_dropout if config.classifier_dropout is not None else config.hidden_dropout_prob
        )
        self.dropout = nn.Dropout(classifier_dropout)
        self.classifier = nn.Linear(config.hidden_size, config.num_labels)
        
        # 이곳에 CRF 레이어를 추가해주세요!
        self.crf = 

        # Initialize weights and apply final processing
        self.post_init()

    def forward(
        self,
        input_ids: Optional[torch.Tensor] = None,
        attention_mask: Optional[torch.Tensor] = None,
        token_type_ids: Optional[torch.Tensor] = None,
        position_ids: Optional[torch.Tensor] = None,
        head_mask: Optional[torch.Tensor] = None,
        inputs_embeds: Optional[torch.Tensor] = None,
        labels: Optional[torch.Tensor] = None,
        output_attentions: Optional[bool] = None,
        output_hidden_states: Optional[bool] = None,
        return_dict: Optional[bool] = None,
    ) -> Union[Tuple[torch.Tensor], TokenClassifierOutput]:
        r"""
        labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
            Labels for computing the token classification loss. Indices should be in `[0, ..., config.num_labels - 1]`.
        """
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        outputs = self.bert(
            input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            position_ids=position_ids,
            head_mask=head_mask,
            inputs_embeds=inputs_embeds,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
            return_dict=return_dict,
        )

        sequence_output = outputs[0]

        sequence_output = self.dropout(sequence_output)
        logits = self.classifier(sequence_output)

        loss = None
        if labels is not None:
            
            # 이곳에 CRF 레이어의 계산 결과를 얻기 위해 입력값을 추가하세요.
            log_likelihood, tags = self.crf(), self.crf.decode()
            
            loss = 0 - log_likelihood
        else:
            tags = self.crf.decode(logits)
        tags = torch.Tensor(tags)

        if not return_dict:
            output = (tags,) + outputs[2:]
            return ((loss,) + output) if loss is not None else output

        return loss, tags

# %% [markdown]
# ### 11. BertCRFForTokenClassification

# %%
crf_model = BertCRFForTokenClassification.from_pretrained(MODEL_NAME, num_labels=len(unique_tags))
crf_model.to(device)

trainer = Trainer(
    model=crf_model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=test_dataset            # evaluation dataset
)
# Out:
# Downloading:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertCRFForTokenClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertCRFForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertCRFForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertCRFForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'crf.start_transitions', 'crf.transitions', 'crf.end_transitions']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train() # 1 epoch에 대략 5분 정도 걸립니다.
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 15410
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1927
# /usr/local/lib/python3.7/dist-packages/torchcrf/__init__.py:249: UserWarning: where received a uint8 condition tensor. This behavior is deprecated and will be removed in a future version of PyTorch. Use a boolean condition instead. (Triggered internally at  ../aten/src/ATen/native/TensorCompare.cpp:402.)
#   score = torch.where(mask[i].unsqueeze(1), next_score, score)
#     <div>
#
#       <progress value='1927' max='1927' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1927/1927 11:43, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>414.345700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>180.148600</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>151.874400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>129.690400</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>128.136400</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>117.456000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>104.105700</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>101.069400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>108.555000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>94.984400</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>92.861300</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>91.953700</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>87.191500</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>87.932400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>86.724800</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>84.170200</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>93.312800</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>85.470900</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>82.488400</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./results/checkpoint-500
# Configuration saved in ./results/checkpoint-500/config.json
# Model weights saved in ./results/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to ./results/checkpoint-1000
# Configuration saved in ./results/checkpoint-1000/config.json
# Model weights saved in ./results/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to ./results/checkpoint-1500
# Configuration saved in ./results/checkpoint-1500/config.json
# Model weights saved in ./results/checkpoint-1500/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1927, training_loss=121.63777462336209, metrics={'train_runtime': 706.7701, 'train_samples_per_second': 21.803, 'train_steps_per_second': 2.726, 'total_flos': 1006824391004160.0, 'train_loss': 121.63777462336209, 'epoch': 1.0})

# %%
crf_model = BertCRFForTokenClassification.from_pretrained(MODEL_NAME, num_labels=len(unique_tags))
crf_model.to(device)

trainer = Trainer(
    model=crf_model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=test_dataset            # evaluation dataset
)
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-base-multilingual-cased/snapshots/cf732291d5a8eace7b973ccd13c95ec07b19e734/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11",
#     "12": "LABEL_12",
#     "13": "LABEL_13",
#     "14": "LABEL_14",
#     "15": "LABEL_15",
#     "16": "LABEL_16",
#     "17": "LABEL_17",
#     "18": "LABEL_18",
#     "19": "LABEL_19",
#     "20": "LABEL_20"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_12": 12,
#     "LABEL_13": 13,
#     "LABEL_14": 14,
#     "LABEL_15": 15,
#     "LABEL_16": 16,
#     "LABEL_17": 17,
#     "LABEL_18": 18,
#     "LABEL_19": 19,
#     "LABEL_2": 2,
#     "LABEL_20": 20,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.23.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--bert-base-multilingual-cased/snapshots/cf732291d5a8eace7b973ccd13c95ec07b19e734/pytorch_model.bin
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertCRFForTokenClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertCRFForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertCRFForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertCRFForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['crf.transitions', 'crf.start_transitions', 'classifier.weight', 'classifier.bias', 'crf.end_transitions']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train() # 1 epoch에 대략 5분 정도 걸립니다.
# Out:
# ***** Running training *****
#   Num examples = 15410
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1927
#     <div>
#
#       <progress value='1927' max='1927' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1927/1927 11:26, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>405.805700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>187.874100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>150.618300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>128.853700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>115.142500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>108.929000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>111.137700</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>102.483600</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>105.002700</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>105.967600</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>89.458000</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>86.269200</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>91.391600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>86.079400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>90.266600</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>81.388200</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>91.661300</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>93.725100</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>87.066700</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./results/checkpoint-500
# Configuration saved in ./results/checkpoint-500/config.json
# Model weights saved in ./results/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to ./results/checkpoint-1000
# Configuration saved in ./results/checkpoint-1000/config.json
# Model weights saved in ./results/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to ./results/checkpoint-1500
# Configuration saved in ./results/checkpoint-1500/config.json
# Model weights saved in ./results/checkpoint-1500/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1927, training_loss=121.50081173273709, metrics={'train_runtime': 686.5576, 'train_samples_per_second': 22.445, 'train_steps_per_second': 2.807, 'total_flos': 1006824391004160.0, 'train_loss': 121.50081173273709, 'epoch': 1.0})

# %% [markdown]
# ### 4. New Data Inference with CRF layer

# %%
def ner_crf_inference(text) : 
  
    crf_model.eval()
    text = text.replace(' ', '_')

    predictions, true_labels = [], []
    
    tokenized_sent = ner_tokenizer(text, len(text)+2)
    input_ids = torch.tensor(tokenized_sent['input_ids']).unsqueeze(0).to(device)
    attention_mask = torch.tensor(tokenized_sent['attention_mask']).unsqueeze(0).to(device)
    token_type_ids = torch.tensor(tokenized_sent['token_type_ids']).unsqueeze(0).to(device)    
    
    with torch.no_grad():
        # 앞서 선언한 crf_model에 입력값들을 추가하세요.
        loss, tags = crf_model()
        
    tags = tags.detach().cpu().numpy()
    label_ids = token_type_ids.cpu().numpy()

    # crf_model이 출력하는 tags를 후처리하여 추론 결과를 pred_tags에 선언하세요.
    pred_tags = []

    print('{}\t{}'.format("TOKEN", "TAG"))
    print("===========")
    # for token, tag in zip(tokenizer.decode(tokenized_sent['input_ids']), pred_tags):
    #   print("{:^5}\t{:^5}".format(token, tag))
    for i, tag in enumerate(pred_tags):
        print("{:^5}\t{:^5}".format(tokenizer.convert_ids_to_tokens(tokenized_sent['input_ids'][i]), tag))

# %% [markdown]
# CRF Layer가 추가된 모델의 추론 결과를 CRF Layer를 추가하기 전 딥러닝 모델의 성능과 비교해보세요!

# %%
text = '이순신은 조선 중기의 무신이다.'
ner_crf_inference(text)

# %%
text = '로스트아크는 스마일게이트 RPG가 개발한 쿼터뷰 액션 MMORPG 게임이다.'
ner_crf_inference(text)

# %%
text = '2014년 11월 12일 최초 공개했으며 2018년 11월 7일부터 오픈 베타 테스트를 진행하다 2019년 12월 4일 정식 오픈했다.'
ner_crf_inference(text)

# %%
text = '짜장면 7,000원'
ner_crf_inference(text)
